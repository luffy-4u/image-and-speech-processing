# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image in grayscale
img = cv2.imread('vanacum.webp', cv2.IMREAD_GRAYSCALE)

# Apply Fourier Transform using numpy's FFT function
dft = np.fft.fft2(img)
dft_shift = np.fft.fftshift(dft)  # Shift the zero frequency component to the center

# Calculate the magnitude spectrum
magnitude_spectrum = 20 * np.log(np.abs(dft_shift) + 1)  # Add 1 to avoid log(0)

# Inverse Fourier Transform to reconstruct the image
f_ishift = np.fft.ifftshift(dft_shift)  # Shift back (inverse shift)
img_back = np.fft.ifft2(f_ishift)       # Inverse FFT
img_back = np.abs(img_back)              # Get the absolute value

# Display the results
plt.figure(figsize=(12, 6))

# Original Image
plt.subplot(1, 3, 1)
plt.title("Original Image")
plt.imshow(img, cmap='gray')
plt.axis('off')

# Magnitude Spectrum
plt.subplot(1, 3, 2)
plt.title("Magnitude Spectrum")
plt.imshow(magnitude_spectrum, cmap='gray')
plt.axis('off')

# Reconstructed Image
plt.subplot(1, 3, 3)
plt.title("Reconstructed Image")
plt.imshow(img_back, cmap='gray')
plt.axis('off')

plt.tight_layout()
plt.show()
